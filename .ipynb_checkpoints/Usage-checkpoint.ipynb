# %% [markdown]
# Libraries

# %%
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup

import re

import utils as lf

# %%
lf.get_table('2liga')
# Out:
#    Poz              Zespół Mecze_rozegrane  Pkt.  Pkt.  Z  R  P  BZ  BS  +/-  \
# 0    1     Husaria Mokotów               8     1    21  7  0  1  70  20   50
# 1    2       Dziki Młochów               8     2    18  6  0  2  53  35   18
# 2    3  UEFA Mafia Ursynów               8     3    15  5  0  3  48  38   10
# 3    4        KSB Warszawa               8     4    15  5  0  3  68  49   19
# 4    5      Orzeły Stolicy               8     5    13  4  1  3  33  26    7
# 5    6      AFC Goodfellas               8     6    10  3  1  4  37  47  -10
# 6    7       Green Lantern               8     7     9  3  0  5  43  58  -15
# 7    8    Tylko Zwycięstwo               8     8     9  3  0  5  28  47  -19
# 8    9  Warszawska Ferajna               8     9     6  2  0  6  22  61  -39
# 9   10            Korsarze               8    10     2  1  0  7  27  48  -21
#
#        Forma
# 0  W,W,P,W,W
# 1  W,W,W,P,W
# 2  W,W,W,W,W
# 3  W,W,P,P,P
# 4  P,P,P,W,W
# 5  W,W,P,W,P
# 6  P,P,W,P,W
# ...

# %%
# Index improvement needed
lf.get_matches('2liga', round_=7)
# Out:
#    Kol.        Data  Godz.           Gospodarz                        Gość  \
# 2     7  2023-11-12  09:00       Dziki Młochów   7 : 4    Tylko Zwycięstwo
# 2     7  2023-11-12  14:00      Orzeły Stolicy   3 : 5     Husaria Mokotów
# 2     7  2023-11-12  17:00            Korsarze   3 : 8      AFC Goodfellas
# 2     7  2023-11-12  19:00  UEFA Mafia Ursynów   8 : 2  Warszawska Ferajna
# 2     7  2023-11-12  19:00       Green Lantern  6 : 18        KSB Warszawa
#
#   Video                 Sędzia     Boisko  Raport
# 2            Volodymyr Molokov  Arena AWF  Raport
# 2            Volodymyr Molokov  Arena AWF  Raport
# 2            Volodymyr Molokov  Arena AWF  Raport
# 2            Piotr Krajczyński  Arena AWF  Raport
# 2          Rafał Szczytniewski  Arena AWF  Raport
